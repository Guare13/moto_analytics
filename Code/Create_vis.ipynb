# %% [markdown]
# Code to create a comparative chart of a motorcycle model considering:
#
# - Year of registration
# - Kilometers (Km)
# - Price

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Upload the dataset
df = pd.read_csv('C:/Users/Alex/Documents/Python Scripts/Moto/Z900.csv')

# %%
# Create the visualization
plt.scatter(df['Km'], df['Precio'], c=df['Año'], cmap='viridis')
plt.colorbar(label='Año')
plt.xlabel('Kilómetros')
plt.ylabel('Precio')
plt.title('Comparación de motos')
plt.show()
